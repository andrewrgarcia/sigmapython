# %%
from pdsfit import *

ex1 = np.random.normal(10, 10, 1000)
ex2 = 2*np.random.uniform(1,40, 1000) + np.random.normal(10, 10, 1000)
ex3 = 3*np.random.exponential(4,1000)

make(ex3,'example 3',bins=20,xlims='')
# Out:
# example 3
# normal_mean 11.83203023952039
# normal_sdev 12.082141128345148
#
# example 3
# lognorm_s/sigma 0.9794778635387769
# lognorm_loc -0.7829422002296691
# lognorm_scale/median/exp_mean 8.206953791274808
#
# example 3
# expon_loc 0.013960458517998472
# expon_scale 11.818069781002393
#
# example 3
# gamma_a 0.9720174254640553
# gamma_b 0.013960446175095197
# gamma_c 12.229470624405025
#
# example 3
# beta_a 0.9649916838612356
# beta_b 84.97234651698473
# beta_c 0.01396045851799847
# beta_d 1057.3170162689626
# ['normal_mean', 'normal_sdev', 'lognorm_s/sigma', 'lognorm_loc', 'lognorm_scale/median/exp_mean', 'expon_loc', 'expon_scale', 'gamma_a', 'gamma_b', 'gamma_c', 'beta_a', 'beta_b', 'beta_c', 'beta_d']
# [11.83203023952039, 12.082141128345148, 0.9794778635387769, -0.7829422002296691, 8.206953791274808, 0.013960458517998472, 11.818069781002393, 0.9720174254640553, 0.013960446175095197, 12.229470624405025, 0.9649916838612356, 84.97234651698473, 0.01396045851799847, 1057.3170162689626]
# (['normal_mean',
#   'normal_sdev',
#   'lognorm_s/sigma',
#   'lognorm_loc',
#   'lognorm_scale/median/exp_mean',
#   'expon_loc',
#   'expon_scale',
#   'gamma_a',
#   'gamma_b',
#   'gamma_c',
#   'beta_a',
#   'beta_b',
#   'beta_c',
#   'beta_d'],
#  [11.83203023952039,
#   12.082141128345148,
#   0.9794778635387769,
#   -0.7829422002296691,
#   8.206953791274808,
#   0.013960458517998472,
#   11.818069781002393,
#   0.9720174254640553,
#   0.013960446175095197,
#   12.229470624405025,
#   0.9649916838612356,
#   84.97234651698473,
#   0.01396045851799847,
#   1057.3170162689626])
